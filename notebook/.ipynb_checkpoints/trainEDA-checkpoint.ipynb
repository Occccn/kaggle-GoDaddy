# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
loss = pd.read_csv('../src/latest/train/loss.csv')
inf =  pd.read_csv('../src/latest/train/inferenced.csv')
train = pd.read_csv('../data/raw/train.csv')
census = pd.read_csv('../data/raw/census_starter.csv')

# %%
plt.figure(figsize = (16,8))
sns.histplot(loss['val_loss'],bins = np.linspace(0,100,21),color = 'royalblue',label = 'val')
sns.histplot(loss['sub_loss'],bins = np.linspace(0,100,21),color = 'gray',label = 'sub')
plt.xlabel('loss')
plt.legend()

# %%
#外部データとlossそのものの相関は弱い

# %%
plt.figure(figsize = (8,8))
plt.scatter(loss['val_loss'],loss['sub_loss'],color = 'royalblue',alpha = 0.1)
plt.xlabel('val_loss')
plt.ylabel('sub_loss')
plt.xlim(-1,10)
plt.ylim(-1,10)
# Out:
# (-1.0, 10.0)

# %%
loss_census_active['active'].mean()
# Out:
# 6442.858217805572

# %%
sns.histplot(loss_census_active['active'],bins = np.linspace(0,10000,21))
# Out:
# <AxesSubplot:xlabel='active', ylabel='Count'>

# %%
loss_cfips = loss[(loss['val_loss'] > 4.5) & loss['val_loss'] < 4.6]['cfips'].values

# %%
train[train['cfips'] == 1123].iloc[1]
# Out:
# row_id                     1123_2019-09-01
# cfips                                 1123
# county                   Tallapoosa County
# state                              Alabama
# first_day_of_month              2019-09-01
# microbusiness_density             3.441289
# active                                1104
# Name: 2380, dtype: object

# %%
train[train['cfips'] == 1133].iloc[1]
# Out:
# row_id                   1133_2019-09-01
# cfips                               1133
# county                    Winston County
# state                            Alabama
# first_day_of_month            2019-09-01
# microbusiness_density           1.245843
# active                               236
# Name: 2575, dtype: object

# %%
train['microbusiness_density'] / train['active']

# %%
train[train['cfips'] == 1001]
# Out:
#              row_id  cfips          county    state first_day_of_month  \
# 0   1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1   1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2   1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3   1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4   1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
# 5   1001_2020-01-01   1001  Autauga County  Alabama         2020-01-01
# 6   1001_2020-02-01   1001  Autauga County  Alabama         2020-02-01
# 7   1001_2020-03-01   1001  Autauga County  Alabama         2020-03-01
# 8   1001_2020-04-01   1001  Autauga County  Alabama         2020-04-01
# 9   1001_2020-05-01   1001  Autauga County  Alabama         2020-05-01
# 10  1001_2020-06-01   1001  Autauga County  Alabama         2020-06-01
# 11  1001_2020-07-01   1001  Autauga County  Alabama         2020-07-01
# 12  1001_2020-08-01   1001  Autauga County  Alabama         2020-08-01
# 13  1001_2020-09-01   1001  Autauga County  Alabama         2020-09-01
# 14  1001_2020-10-01   1001  Autauga County  Alabama         2020-10-01
# 15  1001_2020-11-01   1001  Autauga County  Alabama         2020-11-01
# 16  1001_2020-12-01   1001  Autauga County  Alabama         2020-12-01
# 17  1001_2021-01-01   1001  Autauga County  Alabama         2021-01-01
# 18  1001_2021-02-01   1001  Autauga County  Alabama         2021-02-01
# 19  1001_2021-03-01   1001  Autauga County  Alabama         2021-03-01
# 20  1001_2021-04-01   1001  Autauga County  Alabama         2021-04-01
# 21  1001_2021-05-01   1001  Autauga County  Alabama         2021-05-01
# 22  1001_2021-06-01   1001  Autauga County  Alabama         2021-06-01
# 23  1001_2021-07-01   1001  Autauga County  Alabama         2021-07-01
# 24  1001_2021-08-01   1001  Autauga County  Alabama         2021-08-01
# 25  1001_2021-09-01   1001  Autauga County  Alabama         2021-09-01
# 26  1001_2021-10-01   1001  Autauga County  Alabama         2021-10-01
# 27  1001_2021-11-01   1001  Autauga County  Alabama         2021-11-01
# 35    07  0.091773
# 36    08  0.014119
# 37    09  0.018825
# 38    10  0.021178

# %%
train['microbusiness_density_shift1'] = train.groupby('cfips')['microbusiness_density'].shift(1)

# %%
train['diff'] = train['microbusiness_density_shift1']- train['microbusiness_density']

# %%
train['month']= train['first_day_of_month'].apply(lambda x: x[5:7])

# %%
sns.histplot(train[train['month'] == '02']['diff'], bins = np.linspace(-10,10,11))
plt.yscale('log')

# %%
train[train['month'] == '03']['diff'].min()
# Out:
# -30.810834200000002

# %%
train[train['month'] == '02']['diff'].max()
# Out:
# 32.9242792

# %%
sns.histplot(train[train['month'] == '09']['diff'], bins = np.linspace(-10,10,11))
plt.yscale('log')

# %%
train['diff_abs'] = train['diff'].abs()
train.groupby(['month'])['diff_abs'].median()
# Out:
# month
# 01    0.029293
# 02    0.041397
# 03    0.026923
# 04    0.024341
# 05    0.019837
# 06    0.019755
# 07    0.027674
# 08    0.021503
# 09    0.023841
# 10    0.018509
# 11    0.026791
# 12    0.017924
# Name: diff_abs, dtype: float64

# %%
plt.plot(train.groupby(['month'])['diff_abs'].median() , marker = 'o')

# %%
sns.histplot(train[train['month'] == '07']['diff'], bins = np.linspace(-3,3,11))
plt.yscale('log')

# %%
for cfip in loss_cfips[:10]:
    plt.figure(figsize = (16,8))
    print(cfip)
    plt.plot(pd.to_datetime(train[train['cfips'] == cfip]['first_day_of_month']), train[train['cfips'] == cfip]['microbusiness_density'],marker = 'o',color = 'royalblue')
    plt.plot(pd.to_datetime(train[train['cfips'] == cfip]['first_day_of_month'])[-4:], inf[f'{cfip}'].values,marker = 'o',color = 'gray')
# Out:
# 1001
# 1003
# 1005
# 1007
# 1009
# 1011
# 1013
# 1015
# 1017
# 1019

# %%
census.columns
# Out:
# Index(['pct_bb_2017', 'pct_bb_2018', 'pct_bb_2019', 'pct_bb_2020',
#        'pct_bb_2021', 'cfips', 'pct_college_2017', 'pct_college_2018',
#        'pct_college_2019', 'pct_college_2020', 'pct_college_2021',
#        'pct_foreign_born_2017', 'pct_foreign_born_2018',
#        'pct_foreign_born_2019', 'pct_foreign_born_2020',
#        'pct_foreign_born_2021', 'pct_it_workers_2017', 'pct_it_workers_2018',
#        'pct_it_workers_2019', 'pct_it_workers_2020', 'pct_it_workers_2021',
#        'median_hh_inc_2017', 'median_hh_inc_2018', 'median_hh_inc_2019',
#        'median_hh_inc_2020', 'median_hh_inc_2021'],
#       dtype='object')

# %%
census_sample = census[['cfips','pct_bb_2021','pct_college_2021','pct_foreign_born_2021','pct_it_workers_2021','median_hh_inc_2021']]

# %%
loss_census = pd.merge(loss,census_sample,on = 'cfips',how = 'inner')
active = train.groupby('cfips')['active'].mean()
loss_census_active = pd.merge(loss_census,active,on = 'cfips',how = 'inner')

# %%
loss_census
# Out:
#       cfips  val_loss  sub_loss  pct_bb_2021  pct_college_2021  \
# 0      1001  2.341830  1.777248         85.5              16.4
# 1      1003  0.532225  2.022442         87.9              20.6
# 2      1005  1.637842  0.703457         64.6               6.7
# 3      1007  4.035242  2.185854         74.6               7.9
# 4      1009  2.810553  2.386762         81.0               9.3
# ...     ...       ...       ...          ...               ...
# 3130  56037  1.899199  1.185631         88.4              12.4
# 3131  56039  1.332657  2.581890         90.5              38.3
# 3132  56041  2.577591  4.191443         90.6              12.3
# 3133  56043  2.589565  1.560315         85.4              17.2
# 3134  56045  0.433896  2.290397         81.3              13.9
#
#       pct_foreign_born_2021  pct_it_workers_2021  median_hh_inc_2021
# 0                       2.1                  1.1             62660.0
# 1                       3.5                  1.3             64346.0
# 2                       2.6                  0.8             36422.0
# 3                       1.1                  2.1             54277.0
# 4                       4.5                  0.9             52830.0
# ...                     ...                  ...                 ...
# 3130                    5.5                  1.0             76668.0
# 3131                   11.1                  2.0             94498.0
# 3132                    2.9                  0.9             75106.0
# 3133                    1.0                  1.1             62271.0
# 3134                    1.6                  0.0             65566.0
#
# [3135 rows x 8 columns]

# %%
plt.figure(figsize = (8,8))
plt.scatter(loss_census['sub_loss'], loss_census['pct_college_2021'],color = 'royalblue',alpha = 0.1)
plt.xlim(-1,20)
plt.ylim(-1,50)
# Out:
# (-1.0, 50.0)

# %%
plt.figure(figsize = (8,8))
plt.scatter(loss_census['sub_loss'], loss_census['pct_bb_2021'],color = 'royalblue',alpha = 0.1)
plt.xlim(-1,20)
plt.ylim(40,100)
# Out:
# (40.0, 100.0)

# %%
plt.figure(figsize = (8,8))
plt.scatter(loss_census['sub_loss'], loss_census['pct_foreign_born_2021'],color = 'royalblue',alpha = 0.1)
plt.xlim(-1,20)
plt.ylim(-1,50)
# Out:
# (-1.0, 50.0)

# %%
plt.figure(figsize = (8,8))
plt.scatter(loss_census['sub_loss'], loss_census['pct_it_workers_2021'],color = 'royalblue',alpha = 0.1)
plt.xlim(-1,20)
plt.ylim(-1,10)
# Out:
# (-1.0, 10.0)

# %%
plt.figure(figsize = (8,8))
plt.scatter(loss_census['sub_loss'], loss_census['median_hh_inc_2021'],color = 'royalblue',alpha = 0.1)
plt.xlim(-1,20)
# plt.ylim(-1,10)
# Out:
# (-1.0, 20.0)

# %%
active = train.groupby('cfips')['active'].mean()

# %%
tmp = loss_census_active[loss_census_active['sub_loss'] > 20]
plt.figure(figsize = (8,8))
plt.scatter(tmp['sub_loss'], tmp['active'],color = 'royalblue',alpha = 0.1)

# %%
loss_census_active.iloc[:,1:].corr()
# Out:
#                        val_loss  sub_loss  pct_bb_2021  pct_college_2021  \
# val_loss               1.000000  0.807826    -0.135252         -0.096748
# sub_loss               0.807826  1.000000    -0.081595         -0.053979
# pct_bb_2021           -0.135252 -0.081595     1.000000          0.632990
# pct_college_2021      -0.096748 -0.053979     0.632990          1.000000
# pct_foreign_born_2021 -0.040984 -0.037852     0.301668          0.335906
# pct_it_workers_2021   -0.049292 -0.021873     0.279449          0.349885
# median_hh_inc_2021    -0.088038 -0.055938     0.694960          0.714467
# active                -0.028221 -0.022648     0.205643          0.279146
#
#                        pct_foreign_born_2021  pct_it_workers_2021  \
# val_loss                           -0.040984            -0.049292
# sub_loss                           -0.037852            -0.021873
# pct_bb_2021                         0.301668             0.279449
# pct_college_2021                    0.335906             0.349885
# pct_foreign_born_2021               1.000000             0.200730
# pct_it_workers_2021                 0.200730             1.000000
# median_hh_inc_2021                  0.397858             0.305265
# active                              0.433302             0.244328
#
#                        median_hh_inc_2021    active
# val_loss                        -0.088038 -0.028221
# sub_loss                        -0.055938 -0.022648
# pct_bb_2021                      0.694960  0.205643
# pct_college_2021                 0.714467  0.279146
# pct_foreign_born_2021            0.397858  0.433302
# pct_it_workers_2021              0.305265  0.244328
# median_hh_inc_2021               1.000000  0.256652
# active                           0.256652  1.000000

# %%
sns.heatmap(loss_census_active.iloc[:,1:].corr() ,cmap='Blues')
# Out:
# <AxesSubplot:>
