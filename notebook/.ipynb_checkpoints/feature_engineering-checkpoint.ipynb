# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
loss = pd.read_csv('../src/latest/train/loss.csv')
inf =  pd.read_csv('../src/latest/train/inferenced.csv')
train = pd.read_csv('../data/raw/train.csv')
census = pd.read_csv('../data/raw/census_starter.csv')

# %%
feature_df = train[['cfips']].copy()

# %%
feature_df
# Out:
#         cfips
# 0        1001
# 1        1001
# 2        1001
# 3        1001
# 4        1001
# ...       ...
# 122260  56045
# 122261  56045
# 122262  56045
# 122263  56045
# 122264  56045
#
# [122265 rows x 1 columns]

# %%
#型変換
train['first_day_of_month'] = pd.to_datetime(train['first_day_of_month'])

# %%
##diff特徴量
train['microbusiness_density_shift1'] = train.groupby('cfips')['microbusiness_density'].shift(1)
train['diff'] = train['microbusiness_density_shift1']- train['microbusiness_density']
train['diff_abs'] = train['diff'].abs()
train_old = train[train['first_day_of_month'] < pd.to_datetime('2021/2/1')]
train_old_gby = train_old.groupby('cfips')['diff_abs'].mean().reset_index()
train_diff = train[train['first_day_of_month'] == pd.to_datetime('2021/2/1')][['cfips','diff']]
diff_feature = pd.merge(train_old_gby, train_diff,on = 'cfips')
diff_feature['diff_1_2'] = diff_feature['diff_y']/diff_feature['diff_x']

# %%
len(train_new['first_day_of_month'].unique())
# Out:
# 21

# %%
##ラグ特徴量
lag_features = train[train['first_day_of_month'] >= pd.to_datetime('2021/2/1')]
lag_features_col = []
for shift_month in range(1,len(lag_features['first_day_of_month'].unique())):
    lag_features[f'mb_dens_shift{shift_month}'] = lag_features.groupby(['cfips'])[['microbusiness_density']].shift(shift_month)
    lag_features_col.append(f'mb_dens_shift{shift_month}')
lag_features = lag_features.groupby(['cfips'])[lag_features_col].last().reset_index()
# Out:
# <ipython-input-102-d6f8e85fcfcf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lag_features[f'mb_dens_shift{shift_month}'] = lag_features.groupby(['cfips'])[['microbusiness_density']].shift(shift_month)

# %%
lag_features
# Out:
#       cfips  mb_dens_shift1  mb_dens_shift2  mb_dens_shift3  mb_dens_shift4  \
# 0      1001        3.442677        3.423852        3.437971        3.346197
# 1      1003        8.341701        8.491150        8.573463        8.507496
# 2      1005        1.206827        1.196728        1.216926        1.191678
# 3      1007        1.315346        1.292861        1.326588        1.275998
# 4      1009        1.852060        1.836289        1.831783        1.773202
# ...     ...             ...             ...             ...             ...
# 3130  56037        2.811320        2.811320        2.836282        2.783238
# 3131  56039       26.090586       26.085369       25.939260       25.652266
# 3132  56041        3.995591        3.974924        3.981813        3.906035
# 3133  56043        3.209264        3.209264        3.225807        3.126551
# 3134  56045        1.785395        1.785395        1.803249        1.803249
#
#       mb_dens_shift5  mb_dens_shift6  mb_dens_shift7  mb_dens_shift8  \
# 0           3.313253        3.372082        3.336785        3.334431
# 1           7.907365        7.979170        7.945311        7.823300
# 2           1.186629        1.191678        1.196728        1.206827
# 3           1.247892        1.253513        1.264755        1.236650
# 4           1.748417        1.764189        1.797986        1.777708
# ...              ...             ...             ...             ...
# 3130        2.820681        2.851883        2.848763        2.892446
# 3131       25.506157       25.626175       25.636610       25.438322
# 3132        3.885368        4.064481        4.023147        3.954258
# 3133        2.944582        2.977668        3.010753        3.027295
# 3134        1.803249        1.767542        1.767542        1.749688
#
#       mb_dens_shift9  ...  mb_dens_shift11  mb_dens_shift12  mb_dens_shift13  \
# 0           3.296781  ...         3.200948         3.203320         3.186722
# 1           7.733397  ...         7.900597         7.832168         7.802155
# 2           1.186629  ...         1.151890         1.136930         1.121971
# 3           1.214165  ...         1.231665         1.186877         1.186877
# 4           1.752923  ...         1.733947         1.731690         1.729432
# ...              ...  ...              ...              ...              ...
# 3130        2.926768  ...         3.093138         3.255770         3.362107
# 3131       25.532248  ...        25.666065        25.628914        25.517462
# 3132        3.754478  ...         3.481318         3.501999         3.481318
# 3133        3.027295  ...         3.058357         3.124483         3.058357
# 3134        1.749688  ...         1.760374         1.670559         1.688522
#
#       mb_dens_shift14  mb_dens_shift15  mb_dens_shift16  mb_dens_shift17  \
# 0            3.219917         3.210433         3.222288         3.227030
# 1            7.918605         7.984033         8.077073         8.061466
# 2            1.156876         1.146903         1.107011         1.097038
# 3            1.209271         1.237263         1.237263         1.259657
# 4            1.711370         1.715885         1.713628         1.720401
# ...               ...              ...              ...              ...
# 3130         3.452806         3.434040         3.487208         3.449678
# 3131        25.719137        25.602377        25.655451        25.591763
# 3132         3.439956         3.364125         3.364125         3.426168
# 3133         3.107952         3.124483         3.124483         3.157547
# 3134         1.670559         1.652596         1.652596         1.688522
#
#       mb_dens_shift18  mb_dens_shift19  mb_dens_shift20
# 0            3.224659         3.144043         3.106106
# 1            8.032654         7.978031         7.909001
# 2            1.102025         1.057146         1.072105
# 3            1.259657         1.287650         1.287650
# 4            1.702339         1.700081         1.688793
# ...               ...              ...              ...
# 3130         3.474698         3.540377         3.534121
# 3131        25.581148        25.358242        25.209639
# 3132         3.426168         3.481318         3.467531
# 3133         3.207142         3.256737         3.141015
# 3134         1.724448         1.760374         1.724448
#
# [3135 rows x 21 columns]

# %%
train_new
# Out:
#                   row_id  cfips          county    state first_day_of_month  \
# 18       1001_2021-02-01   1001  Autauga County  Alabama         2021-02-01
# 19       1001_2021-03-01   1001  Autauga County  Alabama         2021-03-01
# 20       1001_2021-04-01   1001  Autauga County  Alabama         2021-04-01
# 21       1001_2021-05-01   1001  Autauga County  Alabama         2021-05-01
# 22       1001_2021-06-01   1001  Autauga County  Alabama         2021-06-01
# ...                  ...    ...             ...      ...                ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming         2022-06-01
# 122261  56045_2022-07-01  56045   Weston County  Wyoming         2022-07-01
# 122262  56045_2022-08-01  56045   Weston County  Wyoming         2022-08-01
# 122263  56045_2022-09-01  56045   Weston County  Wyoming         2022-09-01
# 122264  56045_2022-10-01  56045   Weston County  Wyoming         2022-10-01
#
#         microbusiness_density  active  microbusiness_density_shift1      diff  \
# 18                   3.106106    1310                      2.947244 -0.158862
# 19                   3.144043    1326                      3.106106 -0.037937
# 20                   3.224659    1360                      3.144043 -0.080617
# 21                   3.227030    1361                      3.224659 -0.002371
# 22                   3.222288    1359                      3.227030  0.004742
# ...                       ...     ...                           ...       ...
# 122260               1.803249     101                      1.803249  0.000000
# 122261               1.803249     101                      1.803249  0.000000
# 122262               1.785395     100                      1.803249  0.017854
# 122263               1.785395     100                      1.785395  0.000000
# 122264               1.785395     100                      1.785395  0.000000
#
#         diff_abs  ...  mb_dens_shift11  mb_dens_shift12  mb_dens_shift13  \
# 18      0.158862  ...              NaN              NaN              NaN
# 19      0.037937  ...              NaN              NaN              NaN
# 20      0.080617  ...              NaN              NaN              NaN
# 21      0.002371  ...              NaN              NaN              NaN
# 22      0.004742  ...              NaN              NaN              NaN
# ...          ...  ...              ...              ...              ...
# 122260  0.000000  ...         1.652596         1.652596         1.688522
# 122261  0.000000  ...         1.670559         1.652596         1.652596
# 122262  0.017854  ...         1.688522         1.670559         1.652596
# 122263  0.000000  ...         1.670559         1.688522         1.670559
# 122264  0.000000  ...         1.760374         1.670559         1.688522
#
#         mb_dens_shift14  mb_dens_shift15  mb_dens_shift16  mb_dens_shift17  \
# 18                  NaN              NaN              NaN              NaN
# 19                  NaN              NaN              NaN              NaN
# 20                  NaN              NaN              NaN              NaN
# 21                  NaN              NaN              NaN              NaN
# 22                  NaN              NaN              NaN              NaN
# ...                 ...              ...              ...              ...
# 122260         1.724448         1.760374         1.724448              NaN
# 122261         1.688522         1.724448         1.760374         1.724448
# 122262         1.652596         1.688522         1.724448         1.760374
# 122263         1.652596         1.652596         1.688522         1.724448
# 122264         1.670559         1.652596         1.652596         1.688522
#
#         mb_dens_shift18  mb_dens_shift19  mb_dens_shift20
# 18                  NaN              NaN              NaN
# 19                  NaN              NaN              NaN
# 20                  NaN              NaN              NaN
# 21                  NaN              NaN              NaN
# 22                  NaN              NaN              NaN
# ...                 ...              ...              ...
# 122260              NaN              NaN              NaN
# 122261              NaN              NaN              NaN
# 122262         1.724448              NaN              NaN
# 122263         1.760374         1.724448              NaN
# 122264         1.724448         1.760374         1.724448
#
# [65835 rows x 30 columns]

# %%
sns.histplot(tmp['diff_1_2'],bins = np.linspace(0,100,11))
# Out:
# <AxesSubplot:xlabel='diff_1_2', ylabel='Count'>
